# %% [markdown]
# <a href="https://colab.research.google.com/github/HaleemaAsad0/ALFA-SOLUTIONS/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score

# %% [markdown]
# **data collection + processing**

# %%
# load DF from csv to pandas
credit_dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/creditcard.csv', encoding='latin-1')

# %%
credit_dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
credit_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 75352  56019 -0.330203  1.265306  0.703968  0.943073  0.020692 -0.334221
# 75353  56020 -0.824159  0.689632  0.238364  0.843827 -1.723679  2.003802
# 75354  56020  0.929735 -0.299633  0.394750  0.540756  0.272645  1.656454
# 75355  56021 -1.657683 -0.426294  1.687198 -1.454421 -2.383477  1.305648
# 75356  56021 -1.711121 -0.369377  1.440787  0.136071  0.517265  0.196718
#
#              V7        V8        V9       V10       V11       V12       V13  \
# 75352  0.406527  0.313829 -0.924290 -0.460300 -0.174244  0.930390  1.527143
# 75353  3.194546 -0.727345 -0.680086  0.215221  0.427708  0.053781  0.658958
# 75354 -0.410577  0.600046  0.184701 -0.232993  1.991524  1.531675 -0.203903
# 75355  0.658390  0.543973 -1.068176 -0.674915  0.871448  0.494586  0.385643
# 75356 -0.006951  0.325528 -1.817459  1.052207  1.535350  0.399344  0.092251
#
# ...

# %%
credit_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75357 entries, 0 to 75356
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    75357 non-null  int64
#  1   V1      75357 non-null  float64
#  2   V2      75357 non-null  float64
#  3   V3      75357 non-null  float64
#  4   V4      75357 non-null  float64
#  5   V5      75357 non-null  float64
#  6   V6      75357 non-null  float64
#  7   V7      75357 non-null  float64
#  8   V8      75357 non-null  float64
#  9   V9      75357 non-null  float64
#  10  V10     75357 non-null  float64
#  11  V11     75357 non-null  float64
#  12  V12     75357 non-null  float64
#  13  V13     75357 non-null  float64
#  14  V14     75357 non-null  float64
#  15  V15     75357 non-null  float64
#  16  V16     75357 non-null  float64
#  17  V17     75357 non-null  float64
#  18  V18     75357 non-null  float64
#  19  V19     75357 non-null  float64
# ...

# %%
credit_dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_dataset.shape
# Out:
# (75357, 31)

# %%
# Count the number of legitimate and fraudulent transactions
credit_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    75173
# 1.0      183
# Name: count, dtype: int64

# %%
#separate legit and fraudulent tranactions (0=legit 1=fraud)
Legit = credit_dataset[credit_dataset.Class == 0]
Fraud = credit_dataset[credit_dataset.Class == 1]

# %%
# Display the first few rows of each DataFrame
print("Legit Transactions:")
print(Legit.head())

print("\nFraud Transactions:")
print(Fraud.head())
# Out:
# Legit Transactions:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
print(Legit.shape)
# Out:
# (75173, 31)

# %%
print(Fraud.shape)
# Out:
# (183, 31)

# %%
Legit.Amount.describe()
# Out:
# count    75173.000000
# mean        97.392540
# std        271.227608
# min          0.000000
# 25%          7.690000
# 50%         26.760000
# 75%         88.960000
# max      19656.530000
# Name: Amount, dtype: float64

# %%
Fraud.Amount.describe()
# Out:
# count     183.000000
# mean       95.022350
# std       216.587987
# min         0.000000
# 25%         1.000000
# 50%         7.580000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# Compare mean values of each feature between legitimate and fraudulent transactions
mean_comparison = credit_dataset.groupby('Class').mean()
print(mean_comparison)
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    36121.478576 -0.236877 -0.040266  0.702575  0.153816 -0.263103
# 1.0    31384.775956 -6.777088  4.776050 -9.019596  5.264634 -4.957996
#
#              V6        V7        V8        V9       V10       V11       V12  \
# Class
# 0.0    0.102849 -0.097068  0.046812  0.011383 -0.018079  0.281510 -0.136545
# 1.0   -2.081116 -7.090161  3.259605 -3.145232 -6.723184  4.812034 -7.686873
#
#             V13       V14       V15       V16       V17       V18       V19  \
# Class
# 0.0    0.058698  0.114645  0.162813  0.005872  0.099444 -0.087796 -0.025350
# 1.0    0.144663 -8.029667  0.208467 -5.242944 -8.896095 -3.235686  0.828591
#
#             V20       V21       V22       V23       V24       V25       V26  \
# Class
# 0.0    0.043148 -0.031060 -0.105166 -0.037869  0.007250  0.134982  0.024809
# 1.0    0.384354  0.806585 -0.183346 -0.235990 -0.080063  0.242355  0.098315
#
# ...

# %%
 credit_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    36121.478576 -0.236877 -0.040266  0.702575  0.153816 -0.263103
# 1.0    31384.775956 -6.777088  4.776050 -9.019596  5.264634 -4.957996
#
#              V6        V7        V8        V9       V10       V11       V12  \
# Class
# 0.0    0.102849 -0.097068  0.046812  0.011383 -0.018079  0.281510 -0.136545
# 1.0   -2.081116 -7.090161  3.259605 -3.145232 -6.723184  4.812034 -7.686873
#
#             V13       V14       V15       V16       V17       V18       V19  \
# Class
# 0.0    0.058698  0.114645  0.162813  0.005872  0.099444 -0.087796 -0.025350
# 1.0    0.144663 -8.029667  0.208467 -5.242944 -8.896095 -3.235686  0.828591
#
#             V20       V21       V22       V23       V24       V25       V26  \
# Class
# 0.0    0.043148 -0.031060 -0.105166 -0.037869  0.007250  0.134982  0.024809
# 1.0    0.384354  0.806585 -0.183346 -0.235990 -0.080063  0.242355  0.098315
#
# ...
